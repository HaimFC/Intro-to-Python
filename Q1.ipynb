# %% [markdown]
# #Exercise 1
# Create a program that asks the user to enter their name and their age. Print out
# a message addressed to them that tells them the year that they will turn 100
# years old

# %%
import datetime

print('Enter your name:')
name = input()
print('Enter your age:')
age = input()
currentYear = datetime.date.today().year
print('You will get to 100 year on ' + str(int(currentYear) + (100 - int(age))))
# Out:
# Enter your name:
# Haim
# Enter your age:
# 28
# You will get to 100 year on 2096
